# %%
def addition(a,b):
    return a+b

addition(2,3)
# Out:
# 5

# %%
addition=lambda a,b:a+b
type(addition)
# Out:
# function

# %%
print(addition(5,6))
# Out:
# 11

# %%
def even(num):
    if num%2==0:
        return True
    
even(24)
# Out:
# True

# %%
even1=lambda num:num%2==0
even1(12)
# Out:
# True

# %%
def addition(x,y,z):
    return x+y+z
addition(12,3222,999999999999999999999)
# Out:
# 1000000000000000003233

# %%
addition1=lambda x,y,z:x+y+z
addition(10,10-1,10-2)
# Out:
# 27

# %%
numbers=[1,2,3,4,5,6]
def square(number):
    return number**2

square(22)
# Out:
# 484

# %%
list(map(lambda x:x**2, numbers))
# Out:
# [1, 4, 9, 16, 25, 36]
